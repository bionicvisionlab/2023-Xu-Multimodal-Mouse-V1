# %%
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
# path = "correlation npy-20230516T174345Z-001/"

# %%
# corr_vis = np.load("cnn_070921_J553RT.npy")
# corr_vis_sorted = corr_vis[0].argsort()[::-1]
# corr_beh = np.load("cnn_comb_gru_070921_J553RT_seq_1.npy")
# corr_beh_sorted = corr_beh[0].argsort()[::-1]

# %%
mouse = "070921_J553RT"
corr_vis = np.load("corr_cnn_shifter/" + f"{mouse}_shifter_False_seq_1.npy")
corr_beh = np.load("corr_cnn_gru_shifter/" + f"{mouse}_seq_1.npy")

fig, ax = plt.subplots()
ax.scatter(corr_vis[0], corr_beh[0], alpha=.6, s=100)
ax.plot([0, 1], [0, 1], 'k--')
ax.axis('equal')
fig.savefig(f'scatter-{mouse}.pdf', transparent=True)

# %%
plt.hist(corr_beh[0] - corr_vis[0], range=(-0.2, 0.2), ec='k', bins=21)
plt.savefig(f'hist-{mouse}.pdf')

# %%
mouse = "110421_J569LT"
corr_vis = np.load("corr_cnn_shifter/" + f"{mouse}_shifter_False_seq_1.npy")
corr_beh = np.load("corr_cnn_gru_shifter/" + f"{mouse}_seq_1.npy")

fig, ax = plt.subplots()
# ax.scatter(0.2, 0.8)
ax.scatter(corr_vis[0], corr_beh[0], alpha=.6, s=100, color="orange")
ax.plot([0, 1], [0, 1], 'k--')
ax.axis('equal')
fig.savefig(f'scatter-{mouse}.pdf', transparent=True)

# %%
# plt.hist([0,0], range=(-0.2, 0.2), ec='k', bins=21)
plt.hist(corr_beh[0] - corr_vis[0], range=(-0.2, 0.2), ec='k', bins=21, color="orange")
plt.savefig(f'hist-{mouse}.pdf')

# %%
mouse = "101521_J559NC"
corr_vis = np.load("corr_cnn_shifter/" + f"{mouse}_shifter_False_seq_1.npy")
corr_beh = np.load("corr_cnn_gru_shifter/" + f"{mouse}_seq_1.npy")

fig, ax = plt.subplots()
# ax.scatter(0.2, 0.8)
# ax.scatter(0.8, 0.2)
ax.scatter(corr_vis[0], corr_beh[0], alpha=.6, s=100, color="green")
ax.plot([0, 1], [0, 1], 'k--')
ax.axis('equal')
fig.savefig(f'scatter-{mouse}.pdf', transparent=True)

# %%
# plt.hist([0,0], range=(-0.2, 0.2), ec='k', bins=21)
# plt.hist([0,0], range=(-0.2, 0.2), ec='k', bins=21)
plt.hist(corr_beh[0] - corr_vis[0], range=(-0.2, 0.2), ec='k', bins=21, color="green")
plt.savefig(f'hist-{mouse}.pdf')
